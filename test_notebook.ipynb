# %%
# Simple Test Notebook
print("Hello from Git version 1!")

# Basic calculation
x = 10
y = 20
result = x + y
print(f"The sum of {x} and {y} is {result}")
# Out:
# Hello from Git version 1!
# The sum of 10 and 20 is 30

# %%
# Version 2 changes - added a new function
def greet_user(name):
    return f"Hello, {name}! Welcome to version 2!"

# Test the function
print(greet_user("Jose"))

# More calculations
numbers = [1, 2, 3, 4, 5]
total = sum(numbers)
print(f"The sum of {numbers} is {total}")
# Out:
# Hello, Jose! Welcome to version 2!
# The sum of [1, 2, 3, 4, 5] is 15
