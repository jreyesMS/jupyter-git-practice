# %%
# Simple Test Notebook
print("Hello from Git version 1!")

# Basic calculation
x = 10
y = 20
result = x + y
print(f"The sum of {x} and {y} is {result}")
# Out:
# Hello from Git version 1!
# The sum of 10 and 20 is 30

# %%
# Simple Calculator - Version 3

def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

# Test it
print("Calculator Test:")
print(f"10 + 5 = {add(10, 5)}")
print(f"10 - 5 = {subtract(10, 5)}")
# Out:
# Calculator Test:
# 10 + 5 = 15
# 10 - 5 = 5

# %% [markdown]
# ### Step 5: Run and Save
#
# 1. Run the cell (Shift + Enter) to make sure it works
# 2. **Save the notebook**: File → Save and Checkpoint (or Ctrl+S)
#
# ---
#
# ### Step 6: Go Back to GitHub Desktop
#
# Switch back to **GitHub Desktop**. You should automatically see:
#
# **Left Panel (Changes):**
# - ✅ `test_notebook.ipynb` with a checkmark
#
# **Right Panel:**
# - Green lines showing what you added
#
# ---
#
# ### Step 7: Commit Your Changes
#
# At the **bottom left** of GitHub Desktop:
#
# 1. **Summary:** Type a short description:
# ```
#    Added calculator functions
# ```
#
# 2. **Description (optional):** You can leave this blank or add:
# ```
#    Added simple add and subtract functions
